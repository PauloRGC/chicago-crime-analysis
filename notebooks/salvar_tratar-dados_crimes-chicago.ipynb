# %%
# !pip install pandas-gbq --quiet

# %%
import pandas as pd
from pandas_gbq import read_gbq
import os

# %%
query = """
  SELECT *
  FROM bigquery-public-data.chicago_crime.crime
  LIMIT 1000
"""

# %%
df = read_gbq(query, project_id='curso-ebac-487022', dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_key            1000 non-null   Int64
#  1   case_number           1000 non-null   object
#  2   date                  1000 non-null   datetime64[us, UTC]
#  3   block                 1000 non-null   object
#  4   iucr                  1000 non-null   object
#  5   primary_type          1000 non-null   object
#  6   description           1000 non-null   object
#  7   location_description  997 non-null    object
#  8   arrest                1000 non-null   boolean
#  9   domestic              1000 non-null   boolean
#  10  beat                  1000 non-null   Int64
#  11  district              1000 non-null   Int64
#  12  ward                  941 non-null    Int64
#  13  community_area        940 non-null    Int64
#  14  fbi_code              1000 non-null   object
#  15  x_coordinate          987 non-null    float64
#  16  y_coordinate          987 non-null    float64
#  17  year                  1000 non-null   Int64
#  18  updated_on            1000 non-null   datetime64[us, UTC]
#  19  latitude              987 non-null    float64
#  20  longitude             987 non-null    float64
#  21  location              987 non-null    object
# dtypes: Int64(6), boolean(2), datetime64[us, UTC](2), float64(4), object(8)
# memory usage: 166.1+ KB

# %%
for col in df.columns:
  print(f"{col}: {df[col].dtype}")
# Out:
# unique_key: Int64
# case_number: object
# date: datetime64[us, UTC]
# block: object
# iucr: object
# primary_type: object
# description: object
# location_description: object
# arrest: boolean
# domestic: boolean
# beat: Int64
# district: Int64
# ward: Int64
# community_area: Int64
# fbi_code: object
# x_coordinate: float64
# y_coordinate: float64
# year: Int64
# updated_on: datetime64[us, UTC]
# latitude: float64
# longitude: float64
# location: object

# %%
df.to_parquet('/content/drive/MyDrive/Colab Notebooks/chicago-crimes-analysis/data/raw/chicago_crime_raw.parquet', index=False)

# %%
raw_path = '/content/drive/MyDrive/Colab Notebooks/chicago-crimes-analysis/data/raw/chicago_crime_raw.parquet'
df = pd.read_parquet(raw_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_key            1000 non-null   Int64
#  1   case_number           1000 non-null   object
#  2   date                  1000 non-null   datetime64[us, UTC]
#  3   block                 1000 non-null   object
#  4   iucr                  1000 non-null   object
#  5   primary_type          1000 non-null   object
#  6   description           1000 non-null   object
#  7   location_description  997 non-null    object
#  8   arrest                1000 non-null   boolean
#  9   domestic              1000 non-null   boolean
#  10  beat                  1000 non-null   Int64
#  11  district              1000 non-null   Int64
#  12  ward                  941 non-null    Int64
#  13  community_area        940 non-null    Int64
#  14  fbi_code              1000 non-null   object
#  15  x_coordinate          987 non-null    float64
#  16  y_coordinate          987 non-null    float64
#  17  year                  1000 non-null   Int64
#  18  updated_on            1000 non-null   datetime64[us, UTC]
#  19  latitude              987 non-null    float64
#  20  longitude             987 non-null    float64
#  21  location              987 non-null    object
# dtypes: Int64(6), boolean(2), datetime64[us, UTC](2), float64(4), object(8)
# memory usage: 166.1+ KB

# %%
import numpy as np
#limpeza
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(' ', '_', regex=False)
)

# %%
if 'unique_key' in df.columns:
  df = df.drop_duplicates(subset='unique_key')
else:
  df= df.drop_duplicates()

# %%
if 'date' in df.columns:
  df['date'] = pd.to_datetime(df['date'], errors='coerce', utc=False)

# %%
for c in ['arrest', 'domestic']:
  if c in df.columns:
    df[c] = df[c].astype('boolean')

# %%
text_cols = ['block', 'primary_type', 'description', 'location_description']
for c in text_cols:
  df[c] = df[c].astype('string').str.strip()

# %%
codigos_cols = ['case_number', 'iucr', 'fbi_code']
for c in codigos_cols:
  df[c] = df[c].astype('string').str.strip()

# %%
for c in ['latitude', 'longitude']:
  if c in df.columns:
    df[c] = pd.to_numeric(df[c], errors='coerce')

# %%
df['location_description'] = df['location_description'].fillna('unknown')

# %%
df = df.drop(columns=['location'], errors ='ignore')

# %%
df.isnull().sum()
# Out:
# unique_key               0
# case_number              0
# date                     0
# block                    0
# iucr                     0
# primary_type             0
# description              0
# location_description     0
# arrest                   0
# domestic                 0
# beat                     0
# district                 0
# ward                    59
# community_area          60
# fbi_code                 0
# x_coordinate            13
# y_coordinate            13
# year                     0
# updated_on               0
# latitude                13
# longitude               13
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_key            1000 non-null   Int64
#  1   case_number           1000 non-null   string
#  2   date                  1000 non-null   datetime64[us, UTC]
#  3   block                 1000 non-null   string
#  4   iucr                  1000 non-null   string
#  5   primary_type          1000 non-null   string
#  6   description           1000 non-null   string
#  7   location_description  1000 non-null   string
#  8   arrest                1000 non-null   boolean
#  9   domestic              1000 non-null   boolean
#  10  beat                  1000 non-null   Int64
#  11  district              1000 non-null   Int64
#  12  ward                  941 non-null    Int64
#  13  community_area        940 non-null    Int64
#  14  fbi_code              1000 non-null   string
#  15  x_coordinate          987 non-null    float64
#  16  y_coordinate          987 non-null    float64
#  17  year                  1000 non-null   Int64
#  18  updated_on            1000 non-null   datetime64[us, UTC]
#  19  latitude              987 non-null    float64
#  20  longitude             987 non-null    float64
# dtypes: Int64(6), boolean(2), datetime64[us, UTC](2), float64(4), string(7)
# memory usage: 158.3 KB

# %%
df.to_parquet('/content/drive/MyDrive/Colab Notebooks/chicago-crimes-analysis/data/processed/chicago_crime_processed.parquet', index=False)

# %%
processed_path = '/content/drive/MyDrive/Colab Notebooks/chicago-crimes-analysis/data/processed/chicago_crime_processed.parquet'
df_processed = pd.read_parquet(processed_path)

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_key            1000 non-null   Int64
#  1   case_number           1000 non-null   string
#  2   date                  1000 non-null   datetime64[us, UTC]
#  3   block                 1000 non-null   string
#  4   iucr                  1000 non-null   string
#  5   primary_type          1000 non-null   string
#  6   description           1000 non-null   string
#  7   location_description  1000 non-null   string
#  8   arrest                1000 non-null   boolean
#  9   domestic              1000 non-null   boolean
#  10  beat                  1000 non-null   Int64
#  11  district              1000 non-null   Int64
#  12  ward                  941 non-null    Int64
#  13  community_area        940 non-null    Int64
#  14  fbi_code              1000 non-null   string
#  15  x_coordinate          987 non-null    float64
#  16  y_coordinate          987 non-null    float64
#  17  year                  1000 non-null   Int64
#  18  updated_on            1000 non-null   datetime64[us, UTC]
#  19  latitude              987 non-null    float64
#  20  longitude             987 non-null    float64
# dtypes: Int64(6), boolean(2), datetime64[us, UTC](2), float64(4), string(7)
# memory usage: 158.3 KB

# %%
df_processed['month'] = df_processed['date'].dt.to_period('M')
df_processed['day_of_week'] = df_processed['date'].dt.day_name()
df_processed['hour'] = df_processed['date'].dt.hour

violent_types = [
    'HOMICIDE',
    'ROBBERY',
    'BATTERY',
    'CRIMINAL SEXUAL ASSAULT',
    'ASSAULT'
]

df_processed['is_violent'] = df_processed['primary_type'].isin(violent_types)
# Out:
# /tmp/ipython-input-1228695550.py:1: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_processed['month'] = df_processed['date'].dt.to_period('M')

# %%
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

df_processed['day_of_week'] = pd.Categorical(df_processed['day_of_week'], categories=order, ordered=True)

# %%
df_processed.head()
# Out:
#    unique_key case_number                      date                block  \
# 0    11308464    JB254831 2018-04-28 20:30:00+00:00     002XX N STATE ST
# 1    13965403    JJ412670 2025-09-13 00:00:00+00:00     002XX N STATE ST
# 2     8124180    HT359035 2011-06-21 13:00:00+00:00   005XX W MADISON ST
# 3    13790909    JJ200184 2025-03-30 15:20:00+00:00      0000X E LAKE ST
# 4    11943977    JD106803 2020-01-06 20:38:00+00:00  0000X W RANDOLPH ST
#
#    iucr             primary_type                     description  \
# 0  0281      CRIM SEXUAL ASSAULT                  NON-AGGRAVATED
# 1  0281  CRIMINAL SEXUAL ASSAULT                  NON-AGGRAVATED
# 2  0312                  ROBBERY  ARMED:KNIFE/CUTTING INSTRUMENT
# 3  0313                  ROBBERY  ARMED - OTHER DANGEROUS WEAPON
# 4  0313                  ROBBERY   ARMED: OTHER DANGEROUS WEAPON
#
#   location_description  arrest  domestic  ...  x_coordinate  y_coordinate  \
# 0          HOTEL/MOTEL   False     False  ...     1176327.0     1901797.0
# 1               STREET   False     False  ...     1176310.0     1902226.0
# 2             SIDEWALK   False     False  ...     1173039.0     1900311.0
# 3    CONVENIENCE STORE   False     False  ...     1176905.0     1901744.0
# 4          HOTEL/MOTEL   False     False  ...     1176068.0     1901284.0
#
#    year                updated_on   latitude  longitude    month  day_of_week  \
# 0  2018 2018-05-10 15:46:13+00:00  41.885888 -87.627942  2018-04     Saturday
# 1  2025 2025-11-02 15:41:09+00:00  41.887066 -87.627992  2025-09     Saturday
# 2  2011 2018-02-10 15:50:01+00:00  41.881884 -87.640060  2011-06      Tuesday
# 3  2025 2025-05-17 15:40:52+00:00  41.885730 -87.625821  2025-03       Sunday
# 4  2020 2020-01-13 15:41:18+00:00  41.884486 -87.628909  2020-01       Monday
#
#   hour  is_violent
# 0   20       False
# 1    0        True
# 2   13        True
# 3   15        True
# 4   20        True
#
# [5 rows x 25 columns]

# %%
df_processed.to_parquet('/content/drive/MyDrive/Colab Notebooks/chicago-crimes-analysis/data/prepared/crimes_chicago_prepared.parquet')

# %%
prepared_path = '/content/drive/MyDrive/Colab Notebooks/chicago-crimes-analysis/data/prepared/crimes_chicago_prepared.parquet'
df_prepared = pd.read_parquet(prepared_path)
df_prepared.head()
# Out:
#    unique_key case_number                      date                block  \
# 0    11308464    JB254831 2018-04-28 20:30:00+00:00     002XX N STATE ST
# 1    13965403    JJ412670 2025-09-13 00:00:00+00:00     002XX N STATE ST
# 2     8124180    HT359035 2011-06-21 13:00:00+00:00   005XX W MADISON ST
# 3    13790909    JJ200184 2025-03-30 15:20:00+00:00      0000X E LAKE ST
# 4    11943977    JD106803 2020-01-06 20:38:00+00:00  0000X W RANDOLPH ST
#
#    iucr             primary_type                     description  \
# 0  0281      CRIM SEXUAL ASSAULT                  NON-AGGRAVATED
# 1  0281  CRIMINAL SEXUAL ASSAULT                  NON-AGGRAVATED
# 2  0312                  ROBBERY  ARMED:KNIFE/CUTTING INSTRUMENT
# 3  0313                  ROBBERY  ARMED - OTHER DANGEROUS WEAPON
# 4  0313                  ROBBERY   ARMED: OTHER DANGEROUS WEAPON
#
#   location_description  arrest  domestic  ...  x_coordinate  y_coordinate  \
# 0          HOTEL/MOTEL   False     False  ...     1176327.0     1901797.0
# 1               STREET   False     False  ...     1176310.0     1902226.0
# 2             SIDEWALK   False     False  ...     1173039.0     1900311.0
# 3    CONVENIENCE STORE   False     False  ...     1176905.0     1901744.0
# 4          HOTEL/MOTEL   False     False  ...     1176068.0     1901284.0
#
#    year                updated_on   latitude  longitude    month  day_of_week  \
# 0  2018 2018-05-10 15:46:13+00:00  41.885888 -87.627942  2018-04     Saturday
# 1  2025 2025-11-02 15:41:09+00:00  41.887066 -87.627992  2025-09     Saturday
# 2  2011 2018-02-10 15:50:01+00:00  41.881884 -87.640060  2011-06      Tuesday
# 3  2025 2025-05-17 15:40:52+00:00  41.885730 -87.625821  2025-03       Sunday
# 4  2020 2020-01-13 15:41:18+00:00  41.884486 -87.628909  2020-01       Monday
#
#   hour  is_violent
# 0   20       False
# 1    0        True
# 2   13        True
# 3   15        True
# 4   20        True
#
# [5 rows x 25 columns]
